# %%
# !pip install -U ginza ja_ginza_electra
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ginza
#   Downloading ginza-5.1.2-py3-none-any.whl (20 kB)
# Collecting ja_ginza_electra
#   Downloading ja_ginza_electra-5.1.2-py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 78.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from ginza) (3.4.4)
# Collecting SudachiPy<0.7.0,>=0.6.2
#   Downloading SudachiPy-0.6.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 83.8 MB/s eta 0:00:00
# Collecting plac>=1.3.3
#   Downloading plac-1.3.5-py2.py3-none-any.whl (22 kB)
# Collecting SudachiDict-core>=20210802
#   Downloading SudachiDict-core-20230110.tar.gz (9.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sudachitra<0.2.0,>=0.1.6
#   Downloading SudachiTra-0.1.7.tar.gz (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 KB 33.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ginza-transformers<0.5.0,>=0.4.0
#   Downloading ginza_transformers-0.4.2-py3-none-any.whl (7.2 kB)
# Collecting spacy-transformers<1.2.0,>=1.1.2
#   Downloading spacy_transformers-1.1.9-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 KB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (0.10.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (0.7.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (3.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.9/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (3.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (2.0.7)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.9/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (6.3.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (1.0.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (2.25.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (3.1.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (8.1.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (23.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (1.22.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (57.4.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (2.4.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (1.10.5)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (1.0.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from spacy-transformers<1.2.0,>=1.1.2->ja_ginza_electra) (1.13.1+cu116)
# Collecting transformers<4.26.0,>=3.4.0
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 103.1 MB/s eta 0:00:00
# Collecting spacy-alignments<1.0.0,>=0.7.2
#   Downloading spacy_alignments-0.9.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 9.2 MB/s eta 0:00:00
# Collecting logzero~=1.7.0
#   Downloading logzero-1.7.0-py2.py3-none-any.whl (16 kB)
# Collecting progressbar2~=3.53.1
#   Downloading progressbar2-3.53.3-py2.py3-none-any.whl (25 kB)
# Collecting tokenizers>=0.10.3
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 85.8 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from progressbar2~=3.53.1->sudachitra<0.2.0,>=0.1.6->ja_ginza_electra) (1.15.0)
# Requirement already satisfied: python-utils>=2.3.0 in /usr/local/lib/python3.9/dist-packages (from progressbar2~=3.53.1->sudachitra<0.2.0,>=0.1.6->ja_ginza_electra) (3.5.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.2.0->ginza) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.2.0->ginza) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.2.0->ginza) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.2.0->ginza) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.2.0->ginza) (1.26.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.2.0->ginza) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.2.0->ginza) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->ja_ginza_electra) (3.9.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->ja_ginza_electra) (2022.6.2)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.13.1-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 21.0 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->ja_ginza_electra) (6.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.9/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.2.0->ginza) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy<3.5.0,>=3.2.0->ginza) (2.1.2)
# Building wheels for collected packages: SudachiDict-core, sudachitra
#   Building wheel for SudachiDict-core (setup.py) ... done
#   Created wheel for SudachiDict-core: filename=SudachiDict_core-20230110-py3-none-any.whl size=71665396 sha256=b135e733b6a4f7ca6f741a687428e2c51f7ec696680922edd282a0019828530d
#   Stored in directory: /root/.cache/pip/wheels/c0/e3/8d/d000c7e384ff57920b30e2ba3343104ee5453d265752a34968
#   Building wheel for sudachitra (setup.py) ... done
#   Created wheel for sudachitra: filename=SudachiTra-0.1.7-py3-none-any.whl size=266095 sha256=e93b8a4a99ecd133360b93617cfa29bb33d898c01a65ae620850c084542e9983
#   Stored in directory: /root/.cache/pip/wheels/fd/83/9a/6e148238723e11d9fc60569f00c6b801bcea964bf96562c98a
# Successfully built SudachiDict-core sudachitra
# Installing collected packages: tokenizers, SudachiPy, plac, logzero, SudachiDict-core, spacy-alignments, progressbar2, huggingface-hub, transformers, sudachitra, spacy-transformers, ginza, ginza-transformers, ja_ginza_electra
#   Attempting uninstall: progressbar2
#     Found existing installation: progressbar2 3.38.0
#     Uninstalling progressbar2-3.38.0:
#       Successfully uninstalled progressbar2-3.38.0
# Successfully installed SudachiDict-core-20230110 SudachiPy-0.6.7 ginza-5.1.2 ginza-transformers-0.4.2 huggingface-hub-0.13.1 ja_ginza_electra-5.1.2 logzero-1.7.0 plac-1.3.5 progressbar2-3.53.3 spacy-alignments-0.9.0 spacy-transformers-1.1.9 sudachitra-0.1.7 tokenizers-0.13.2 transformers-4.25.1

# %%
# !pip install japanize_matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# データの読み込み
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting japanize_matplotlib
#   Downloading japanize-matplotlib-1.1.3.tar.gz (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 90.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from japanize_matplotlib) (3.5.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (4.39.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->japanize_matplotlib) (1.15.0)
# Building wheels for collected packages: japanize_matplotlib
#   Building wheel for japanize_matplotlib (setup.py) ... done
#   Created wheel for japanize_matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120275 sha256=fea4adbcf46cb84552bf815b62b91fc809d2a5a821351b7c0c53f93e22ef0b23
#   Stored in directory: /root/.cache/pip/wheels/91/8f/c2/83055ad0c9591b0a094730aa7cb2cc12fedacbcd2241baf534
# Successfully built japanize_matplotlib
# Installing collected packages: japanize_matplotlib
# Successfully installed japanize_matplotlib-1.1.3

# %%
# count_word.py

from collections import Counter

import spacy
import pandas as pd

# 使用する単語の品詞とストップワードの指定
include_pos = ( 'ADJ') #'NOUN', 'PROPN', 'VERB',
stopwords = ('する', 'ある', 'ない', 'いう', 'もの', 'こと', 'よう',
             'なる', 'ほう', 'いる', 'くる', 'お', 'できる')

# 口コミデータの読み込み
df = high_score
nlp = spacy.load('ja_ginza_electra')
# Out:
# error We couldn't connect to 'https://huggingface.co' to load this file, couldn't find it in the cached files and it looks like megagonlabs/transformers-ud-japanese-electra-base-ginza-510 is not the path to a directory containing a file named config.json.
# Checkout your internet connection or see how to run the library in offline mode at 'https://huggingface.co/docs/transformers/installation#offline-mode'.
# error Can't load the configuration of '/tmp/tmpml_vxvt4/config.json'. If you were trying to load it from 'https://huggingface.co/models', make sure you don't have a local directory with the same name. Otherwise, make sure '/tmp/tmpml_vxvt4/config.json' is the correct path to a directory containing a config.json file
# trying to download model from huggingface hub: megagonlabs/transformers-ud-japanese-electra-base-ginza-510 ...
# Downloading (…)lve/main/config.json:   0%|          | 0.00/815 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/434M [00:00<?, ?B/s]
# succeded

# %%
# count_word.py

from collections import Counter

import spacy
import pandas as pd

# 使用する単語の品詞とストップワードの指定
include_pos = ( 'ADJ') #'NOUN', 'PROPN', 'VERB',
stopwords = ('する', 'ある', 'ない', 'いう', 'もの', 'こと', 'よう',
             'なる', 'ほう', 'いる', 'くる', 'お', 'できる')

# 口コミデータの読み込み
df = high_score
nlp = spacy.load('ja_ginza_electra')


#def review_word(df):
# 口コミに含まれている空行を削除
df['クチコミ'] = df['クチコミ'].replace('\n+', '\n', regex=True)

# 出現する単語をリストに追加
words1 = []
for doc in nlp.pipe(df['クチコミ'] ):
    words1.extend([token.lemma_ for token in doc
                if token.pos_ in include_pos and
                token.lemma_ not in stopwords])

# 単語の頻度をカウント
counter = Counter(words1)

print('count word')
for word1, count in counter.most_common(100):
    print(f'{count:>5} {word1}')

# %%
# count_word.py

from collections import Counter

import spacy
import pandas as pd

# 使用する単語の品詞とストップワードの指定
include_pos = ( 'ADJ') #'NOUN', 'PROPN', 'VERB',
stopwords = ('する', 'ある', 'ない', 'いう', 'もの', 'こと', 'よう',
             'なる', 'ほう', 'いる', 'くる', 'お', 'できる')

# 口コミデータの読み込み
df2 = low_socre
nlp = spacy.load('ja_ginza_electra')

#def review_word(df):
# 口コミに含まれている空行を削除
df2['クチコミ'] = df2['クチコミ'].replace('\n+', '\n', regex=True)

# 出現する単語をリストに追加
words2 = []
for doc in nlp.pipe(df2['クチコミ'] ):
    words2.extend([token.lemma_ for token in doc
                if token.pos_ in include_pos and
                token.lemma_ not in stopwords])

# 単語の頻度をカウント
counter = Counter(words2)

print('count word')
for word2, count2 in counter.most_common(100):
    print(f'{count2:>5} {word2}')

# %%
#使用する単語の品詞とストップワードの指定
include_pos = ( 'ADJ') #'NOUN', 'PROPN', 'VERB',
stopwords = ('する', 'ある', 'ない', 'いう', 'もの', 'こと', 'よう',
             'なる', 'ほう', 'いる', 'くる', 'お', 'できる')

# 口コミデータの読み込み
df3 = review_data[review_data["クチコミ評価点"]>=4]
nlp = spacy.load('ja_ginza_electra')

#def review_word(df):
# 口コミに含まれている空行を削除
df3['クチコミ'] = df3['クチコミ'].replace('\n+', '\n', regex=True)

# 出現する単語をリストに追加
words3 = []
for doc in nlp.pipe(df3['クチコミ'] ):
    words3.extend([token.lemma_ for token in doc
                if token.pos_ in include_pos and
                token.lemma_ not in stopwords])

# 単語の頻度をカウント
counter = Counter(words3)

print('count word')
for word3, count3 in counter.most_common(100):
    print(f'{count3:>5} {word3}')

# %%
#使用する単語の品詞とストップワードの指定
include_pos = ('NOUN', 'PROPN', 'VERB', 'ADJ')
stopwords = ('する', 'ある', 'ない', 'いう', 'もの', 'こと', 'よう',
             'なる', 'ほう', 'いる', 'くる', 'お', 'できる', "思う","方","言う","　", "行く"," ","事","さん")

# 口コミデータの読み込み
df4 = review_data[review_data["クチコミ評価点"]<3]
nlp = spacy.load('ja_ginza_electra')

#def review_word(df):
# 口コミに含まれている空行を削除
df4['クチコミ'] = df4['クチコミ'].replace('\n+', '\n', regex=True)

# 出現する単語をリストに追加
words4 = []
for doc in nlp.pipe(df4['クチコミ'] ):
    words4.extend([token.lemma_ for token in doc
                if token.pos_ in include_pos and
                token.lemma_ not in stopwords])

# 単語の頻度をカウント
counter = Counter(words4)

print('count word')
for word4, count4 in counter.most_common(100):
    print(f'{count4:>5} {word4}')

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
! pip install pyvis
! pip install japanize_matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyvis
#   Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 KB 35.8 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.9/dist-packages (from pyvis) (3.0)
# Collecting jsonpickle>=1.4.1
#   Downloading jsonpickle-3.0.1-py2.py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 KB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: jinja2>=2.9.6 in /usr/local/lib/python3.9/dist-packages (from pyvis) (3.1.2)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from pyvis) (7.9.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 64.0 MB/s eta 0:00:00
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.3.0->pyvis) (5.7.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.3.0->pyvis) (57.4.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=5.3.0->pyvis) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=5.3.0->pyvis) (4.4.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython>=5.3.0->pyvis) (4.8.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.3.0->pyvis) (2.0.10)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2>=2.9.6->pyvis) (2.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.3.0->pyvis) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.3.0->pyvis) (0.2.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect->ipython>=5.3.0->pyvis) (0.7.0)
# Installing collected packages: jsonpickle, jedi, pyvis
# Successfully installed jedi-0.18.2 jsonpickle-3.0.1 pyvis-0.3.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: japanize_matplotlib in /usr/local/lib/python3.9/dist-packages (1.1.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from japanize_matplotlib) (3.5.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (4.39.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (8.4.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (1.22.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (1.4.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->japanize_matplotlib) (1.15.0)

# %%
#使用する単語の品詞とストップワードの指定
include_pos = ('NOUN', 'PROPN', 'VERB', 'ADJ')
stopwords = ('する', 'ある', 'ない', 'いう', 'もの', 'こと', 'よう',
             'なる', 'ほう', 'いる', 'くる', 'お', 'できる', "思う","方","言う","　", "行く"," ","事","さん")

# 口コミデータの読み込み
df4 = review_data[review_data["クチコミ評価"]>=3]
nlp = spacy.load('ja_ginza_electra')

def extract_words(sent, pos_tags, stopwords):
    words = [token.lemma_ for token in sent
             if token.pos_ in pos_tags and token.lemma_ not in stopwords]
    return words

from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

def count_cooccurrence(sents, token_length='{2,}'):
    token_pattern=f'\\b\\w{token_length}\\b'
    count_model = CountVectorizer(token_pattern=token_pattern)

    X = count_model.fit_transform(sents)
    words = count_model.get_feature_names_out()
    word_counts = np.asarray(X.sum(axis=0)).reshape(-1)

    X[X > 0] = 1
    Xc = (X.T * X)
    return words, word_counts, Xc, X
def word_weights(words, word_counts):
    count_max = word_counts.max()
    weights = [(word, {'weight': count / count_max})
               for word, count in zip(words, word_counts)]
    return weights

def cooccurrence_weights(words, Xc, weight_cutoff):
    Xc_max = Xc.max()
    cutoff = weight_cutoff * Xc_max
    weights = [(words[i], words[j], Xc[i,j] / Xc_max)
               for i, j in zip(*Xc.nonzero()) if i < j and Xc[i,j] > cutoff]
    return weights
import networkx as nx
from pyvis.network import Network
import matplotlib.pyplot as plt
import japanize_matplotlib

def create_network(words, word_counts, Xc, weight_cutoff):
    G = nx.Graph()
    weights_w = word_weights(words, word_counts)
    G.add_nodes_from(weights_w)

    weights_c = cooccurrence_weights(words, Xc, weight_cutoff)
    G.add_weighted_edges_from(weights_c)

    G.remove_nodes_from(list(nx.isolates(G)))
    return G

def pyplot_network(G):
    plt.figure(figsize=(10, 10))
    pos = nx.spring_layout(G, k=0.1)

    weights_n = np.array(list(nx.get_node_attributes(G, 'weight').values()))
    nx.draw_networkx_nodes(G, pos, node_size=100 * weights_n)

    weights_e = np.array(list(nx.get_edge_attributes(G, 'weight').values()))
    nx.draw_networkx_edges(G, pos, width=20 * weights_e)

    nx.draw_networkx_labels(G, pos, font_family='IPAexGothic')

    plt.axis("off")
    plt.show()

def nx2pyvis_G(G):
    pyvis_G = Network(width='800px', height='800px', notebook=True)
    for node, attrs in G.nodes(data=True):
        pyvis_G.add_node(node, title=node, size=30 * attrs['weight'])
    for node1, node2, attrs in G.edges(data=True):
        pyvis_G.add_edge(node1, node2, width=20 * attrs['weight'])
    return pyvis_G
# 口コミを解析し共起を算出
sents = []
for doc in nlp.pipe(df4['クチコミ']):
    sents.extend([' '.join(extract_words(sent, include_pos, stopwords))
                  for sent in doc.sents])

words, word_counts, Xc, X = count_cooccurrence(sents, token_length='{1,}')
# ネットワークの生成
G = create_network(words, word_counts, Xc, 0.055)

# 静的ネットワークの描画
pyplot_network(G)

# 動的ネットワークの描画
pyvis_G = nx2pyvis_G(G)
pyvis_G.show('graph.html')

# %%
G = create_network(words, word_counts, Xc, 0.04)

# 静的ネットワークの描画
pyplot_network(G)

# 動的ネットワークの描画
pyvis_G = nx2pyvis_G(G)
pyvis_G.show('graph.html')

# %%
import spacy
#使用する単語の品詞とストップワードの指定
include_pos = ('NOUN', 'PROPN', 'VERB', 'ADJ')
stopwords = ('する', 'ある', 'ない', 'いう', 'もの', 'こと', 'よう',
             'なる', 'ほう', 'いる', 'くる', 'お', 'できる')

# 口コミデータの読み込み
df4 = review_data[review_data["クチコミ評価点"]>=4]
nlp = spacy.load('ja_ginza_electra')

def extract_words(sent, pos_tags, stopwords):
    words = [token.lemma_ for token in sent
             if token.pos_ in pos_tags and token.lemma_ not in stopwords]
    return words

from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

def count_cooccurrence(sents, token_length='{2,}'):
    token_pattern=f'\\b\\w{token_length}\\b'
    count_model = CountVectorizer(token_pattern=token_pattern)

    X = count_model.fit_transform(sents)
    words = count_model.get_feature_names_out()
    word_counts = np.asarray(X.sum(axis=0)).reshape(-1)

    X[X > 0] = 1
    Xc = (X.T * X)
    return words, word_counts, Xc, X
def word_weights(words, word_counts):
    count_max = word_counts.max()
    weights = [(word, {'weight': count / count_max})
               for word, count in zip(words, word_counts)]
    return weights

def cooccurrence_weights(words, Xc, weight_cutoff):
    Xc_max = Xc.max()
    cutoff = weight_cutoff * Xc_max
    weights = [(words[i], words[j], Xc[i,j] / Xc_max)
               for i, j in zip(*Xc.nonzero()) if i < j and Xc[i,j] > cutoff]
    return weights
import networkx as nx
from pyvis.network import Network
import matplotlib.pyplot as plt
import japanize_matplotlib

def create_network(words, word_counts, Xc, weight_cutoff):
    G = nx.Graph()
    weights_w = word_weights(words, word_counts)
    G.add_nodes_from(weights_w)

    weights_c = cooccurrence_weights(words, Xc, weight_cutoff)
    G.add_weighted_edges_from(weights_c)

    G.remove_nodes_from(list(nx.isolates(G)))
    return G

def pyplot_network(G):
    plt.figure(figsize=(10, 10))
    pos = nx.spring_layout(G, k=0.1)

    weights_n = np.array(list(nx.get_node_attributes(G, 'weight').values()))
    nx.draw_networkx_nodes(G, pos, node_size=100 * weights_n)

    weights_e = np.array(list(nx.get_edge_attributes(G, 'weight').values()))
    nx.draw_networkx_edges(G, pos, width=20 * weights_e)

    nx.draw_networkx_labels(G, pos, font_family='IPAexGothic')

    plt.axis("off")
    plt.show()

def nx2pyvis_G(G):
    pyvis_G = Network(width='800px', height='800px', notebook=True)
    for node, attrs in G.nodes(data=True):
        pyvis_G.add_node(node, title=node, size=30 * attrs['weight'])
    for node1, node2, attrs in G.edges(data=True):
        pyvis_G.add_edge(node1, node2, width=20 * attrs['weight'])
    return pyvis_G
# 口コミを解析し共起を算出
sents = []
for doc in nlp.pipe(df4['クチコミ']):
    sents.extend([' '.join(extract_words(sent, include_pos, stopwords))
                  for sent in doc.sents])

words, word_counts, Xc, X = count_cooccurrence(sents, token_length='{1,}')
# ネットワークの生成
G = create_network(words, word_counts, Xc, 0.04)

# %%
# 静的ネットワークの描画
pyplot_network(G)

# 動的ネットワークの描画
pyvis_G = nx2pyvis_G(G)
pyvis_G.show('graph.html')

# %% [markdown]
# 参考文献
# Pythonではじめるテキストアナリティクス入門：サポートページ
# https://github.com/tksakaki/kspub_ds_text_analytics
